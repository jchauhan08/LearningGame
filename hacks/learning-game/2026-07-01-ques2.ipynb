# %% [markdown]
# ---
# layout: post
# title: Pseudocode Question
# authors: Rebecca, Meryl
# permalink: /learninggame/ques2
# ---

# %% [markdown]
# ## Pseudocode Question

# %%
# %%js
#
# // CODE_RUNNER: complete the missing code
# The block code consists of 3 lines.
# Line 1: temp ← first
# Line 2: first ← second
# Line 3: secong ← (Missing Code)
